# %%
# %matplotlib inline
# %run convenience.ipynb
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

np.set_printoptions(precision=2,suppress=True) # numpy output options

pi=np.pi
j=1j

# %% [markdown]
# ### System characterization with Bode plot, step response and pole-zero map

# %%
combinedplot(signal.lti([1],[1,.05,1]))#Be careful to specify a time or frequency range if needed.
#For example, those strange beats in the step response DO NOT EXIST. They are an illusion.

# %%
combinedplot(signal.lti([1],[1,.05,1]),T=np.arange(0,200,.1),w=np.logspace(-2,2,100),axis='tight')
