# %%
# %matplotlib inline
# %run convenience.ipynb
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

np.set_printoptions(precision=2,suppress=True) # numpy output options

pi=np.pi
j=1j

# %% [markdown]
# ### System characterization with Bode plot, step response and pole-zero map

# %%
combinedplot(signal.lti([1],[1,.05,1]))#TODO: specify range of frequencies and/or time step manually. 
#Those strange beats in the step response DO NOT EXIST. They are an illusion. Be careful.
# Out:
# C:\Anaconda\lib\site-packages\matplotlib\axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "
